# %% [markdown]
# <a href="https://colab.research.google.com/github/atikahlestar/Data-Science/blob/main/Project_6_Customer_Adoption_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project 6
# Memprediksi Nasabah Mana yang Lebih Mungkin Berlangganan Deposito Berjangka di Produk Bank.
#
# ### Customers Adoption Dataset
#     Dataset tentang informasi pelanggan dan apakah mereka berlangganan deposito berjangka setelah panggilan.
#
# ### Sumber Data :
# https://www.kaggle.com/datasets/janiobachmann/bank-marketing-dataset

# %% [markdown]
# ### Masalah Bisnis
# Bagaimana cara meningkatkan pendapatan dan mengurangi biaya dengan memprediksi pelanggan mana yang lebih mungkin untuk berlangganan jika ditelepon?
#
# ### Tujuan
# Membangun model klasifikasi untuk memprediksi probabilitas pelanggan akan berlangganan

# %% [markdown]
# ### Data Cleansing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/Shared drives/atikahlestari31/Project/Dataset/bank.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
## Check Missing Value

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
## Check Outliers

# %%
df_num = df.select_dtypes(["int64"])
col_num = df_num.columns
col_num
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for col in col_num:
    print(f"Running for {col}")
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    print(iqr)
    fence_high = q3 + 1.5*iqr
    fence_low = q1 - 1.5*iqr
    outliers = df[(df[col] < fence_low) | (df[col] > fence_high)]
    print(outliers.shape)
# Out:
# Running for age
# 17.0
# (171, 17)
# Running for balance
# 1586.0
# (1055, 17)
# Running for day
# 14.0
# (0, 17)
# Running for duration
# 358.0
# (636, 17)
# Running for campaign
# 2.0
# (601, 17)
# Running for pdays
# 21.75
# (2750, 17)
# Running for previous
# 1.0
# (1258, 17)

# %%
for col in col_num:
    print(f"Running for {col}")
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    print(iqr)
    fence_high = q3 + 1.5*iqr
    fence_low = q1 - 1.5*iqr
    outliers = df[(df[col] < fence_low) | (df[col] > fence_high)]
    df = df[(df[col] >= fence_low) & (df[col] <= fence_high)]
# Out:
# Running for age
# 17.0
# Running for balance
# 1564.5
# Running for day
# 14.0
# Running for duration
# 355.0
# Running for campaign
# 2.0
# Running for pdays
# 83.0
# Running for previous
# 0.0

# %%
df.shape
# Out:
# (6498, 17)

# %%
## Check Duplicated Value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#     age         job  marital  education default  balance housing loan  \
# 3    55    services  married  secondary      no     2476     yes   no
# 4    54      admin.  married   tertiary      no      184      no   no
# 5    42  management   single   tertiary      no        0     yes  yes
# 8    37  technician  married  secondary      no        1     yes   no
# 10   38      admin.   single  secondary      no      100     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 3   unknown    5   may       579         1     -1         0  unknown     yes
# 4   unknown    5   may       673         2     -1         0  unknown     yes
# 5   unknown    5   may       562         2     -1         0  unknown     yes
# 8   unknown    6   may       608         1     -1         0  unknown     yes
# 10  unknown    7   may       786         1     -1         0  unknown     yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6498 entries, 3 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6498 non-null   int64
#  1   job        6498 non-null   object
#  2   marital    6498 non-null   object
#  3   education  6498 non-null   object
#  4   default    6498 non-null   object
#  5   balance    6498 non-null   int64
#  6   housing    6498 non-null   object
#  7   loan       6498 non-null   object
#  8   contact    6498 non-null   object
#  9   day        6498 non-null   int64
#  10  month      6498 non-null   object
#  11  duration   6498 non-null   int64
#  12  campaign   6498 non-null   int64
#  13  pdays      6498 non-null   int64
#  14  previous   6498 non-null   int64
#  15  poutcome   6498 non-null   object
#  16  deposit    6498 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 913.8+ KB

# %%
## Univariate Analysis

# %%
col_num
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
df.describe()
# Out:
#                age      balance          day     duration     campaign  \
# count  6498.000000  6498.000000  6498.000000  6498.000000  6498.000000
# mean     40.222530   749.580025    15.746537   313.542167     2.090951
# std      10.758377   975.325828     8.448083   241.626452     1.303743
# min      18.000000 -2049.000000     1.000000     2.000000     1.000000
# 25%      32.000000    68.000000     8.000000   129.000000     1.000000
# 50%      38.000000   389.500000    16.000000   236.000000     2.000000
# 75%      48.000000  1116.500000    22.000000   440.000000     3.000000
# max      74.000000  4025.000000    31.000000  1023.000000     6.000000
#
#         pdays  previous
# count  6498.0    6498.0
# mean     -1.0       0.0
# std       0.0       0.0
# min      -1.0       0.0
# 25%      -1.0       0.0
# 50%      -1.0       0.0
# 75%      -1.0       0.0
# max      -1.0       0.0

# %%
plt.figure(figsize = [15,7])
for i in range(len(col_num)):
    plt.subplot(2,4, i+1)
    sns.histplot(x = col_num[i], data = df)
    plt.tight_layout()

# %%
## Multivariate Analysis

# %%
sns.pairplot(df[col_num])

# %%
sns.heatmap(df[col_num].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Additional Data Preparation before Modeling

# %%
## Feature Engineering

# %%
df["balance_group"] = "positive"

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# 5       42   management   single   tertiary      no        0     yes  yes
# 8       37   technician  married  secondary      no        1     yes   no
# 10      38       admin.   single  secondary      no      100     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11156   34  blue-collar   single  secondary      no      -72     yes   no
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.loc[df["balance"] < 0, "balance_group"] = "negative"

# %%
df.loc[df["balance"] == 0, "balance_group"] = "empty"

# %%
## One Hot Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6498 entries, 3 to 11161
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            6498 non-null   int64
#  1   job            6498 non-null   object
#  2   marital        6498 non-null   object
#  3   education      6498 non-null   object
#  4   default        6498 non-null   object
#  5   balance        6498 non-null   int64
#  6   housing        6498 non-null   object
#  7   loan           6498 non-null   object
#  8   contact        6498 non-null   object
#  9   day            6498 non-null   int64
#  10  month          6498 non-null   object
#  11  duration       6498 non-null   int64
#  12  campaign       6498 non-null   int64
#  13  pdays          6498 non-null   int64
#  14  previous       6498 non-null   int64
#  15  poutcome       6498 non-null   object
#  16  deposit        6498 non-null   object
#  17  balance_group  6498 non-null   object
# ...

# %%
df.head()
# Out:
#     age         job  marital  education default  balance housing loan  \
# 3    55    services  married  secondary      no     2476     yes   no
# 4    54      admin.  married   tertiary      no      184      no   no
# 5    42  management   single   tertiary      no        0     yes  yes
# 8    37  technician  married  secondary      no        1     yes   no
# 10   38      admin.   single  secondary      no      100     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit  \
# 3   unknown    5   may       579         1     -1         0  unknown     yes
# 4   unknown    5   may       673         2     -1         0  unknown     yes
# 5   unknown    5   may       562         2     -1         0  unknown     yes
# 8   unknown    6   may       608         1     -1         0  unknown     yes
# 10  unknown    7   may       786         1     -1         0  unknown     yes
#
#    balance_group
# 3       positive
# 4       positive
# 5          empty
# ...

# %%
df_obj = df.select_dtypes(["object"])
col_obj = df_obj.columns.tolist()
col_obj
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'deposit',
#  'balance_group']

# %%
col_obj.remove("deposit")
col_obj
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'balance_group']

# %%
df = pd.get_dummies(df, columns = col_obj)

# %%
df
# Out:
#        age  balance  day  duration  campaign  pdays  previous deposit  \
# 3       55     2476    5       579         1     -1         0     yes
# 4       54      184    5       673         2     -1         0     yes
# 5       42        0    5       562         2     -1         0     yes
# 8       37        1    6       608         1     -1         0     yes
# 10      38      100    7       786         1     -1         0     yes
# ...    ...      ...  ...       ...       ...    ...       ...     ...
# 11156   34      -72    7       273         5     -1         0      no
# 11157   33        1   20       257         1     -1         0      no
# 11158   39      733   16        83         4     -1         0      no
# 11159   32       29   19       156         2     -1         0      no
# 11161   34        0    9       628         1     -1         0      no
#
#        job_admin.  job_blue-collar  ...  month_jun  month_mar  month_may  \
# ...

# %%
## Train Test Split

# %%
X = df.drop(columns = ["deposit"])
y = df["deposit"].map({"yes" : 1, "no" :0})

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4548, 51)
# (1950, 51)
# (4548,)
# (1950,)

# %% [markdown]
# ### Modeling

# %%
## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
## Hyperparameter Tuning

params = {
    "max_depth" : [2,3,5,10,15],
    "min_samples_leaf" : [20,30,50,100]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator = RandomForestClassifier(),
                           param_grid = params,
                           cv = 5,
                           scoring = "roc_auc"
                          )
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 3, 5, 10, 15],
#                          'min_samples_leaf': [20, 30, 50, 100]},
#              scoring='roc_auc')

# %%
rf_best = grid_search.best_estimator_
rf_best.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_leaf=20)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import recall_score

y_dtree = dtree.predict(X_test)
y_rf = rf.predict(X_test)
y_rf_best = rf_best.predict(X_test)

# %%
print(recall_score(y_test, y_dtree, pos_label = 1, average = "binary"))
print(recall_score(y_test, y_rf, pos_label = 1, average = "binary"))
print(recall_score(y_test, y_rf_best, pos_label = 1, average = "binary"))
# Out:
# 0.6713881019830028
# 0.7889518413597734
# 0.726628895184136

# %%
from sklearn.metrics import precision_score

print(precision_score(y_test, y_dtree, pos_label = 1, average = "binary"))
print(precision_score(y_test, y_rf, pos_label = 1, average = "binary"))
print(precision_score(y_test, y_rf_best, pos_label = 1, average = "binary"))
# Out:
# 0.7236641221374046
# 0.7651098901098901
# 0.7510980966325037

# %%
from sklearn.metrics import roc_auc_score

y_prob_dtree = dtree.predict_proba(X_test)[:,1]
y_prob_rf = rf.predict_proba(X_test)[:,1]
y_prob_rf_best = rf_best.predict_proba(X_test)[:,1]

# %%
print(roc_auc_score(y_test, y_prob_dtree))
print(roc_auc_score(y_test, y_prob_rf))
print(roc_auc_score(y_test, y_prob_rf_best))
# Out:
# 0.7629448548500223
# 0.9057572666077626
# 0.8922203346601931

# %% [markdown]
# ### Kesimpulan Bisnis

# %% [markdown]
# #### Dampak Bisnis

# %%
# Final Model : Random Forest without Hyperparameter Tuning
# Precision = 76%, Recall = 79%

# Asumsikan dari setiap 100 pelanggan, 20 akan berlangganan

# Sebelum model:
    # Kita tidak tahu siapa yang lebih mungkin berlangganan, jadi kita menghubungi semua orang.
    # Biaya: 100 * 10K = 1 juta.
    # Pendapatan = 20 * 100K = 2 juta.
    # Keuntungan = 1 juta.

# Setelah model:
    # Biaya: Berlangganan/Presisi * 10K.
    #    = 20/0.76 * 10K
    #    = 26*10K = 260K
    # Pendapatan = (Recall * Berlangganan) * 100K
    #    = (0.79*20) * 100K
    #    = 1.58 * 100K = 1.58 mio
    # Keuntungan = 1,3 juta.
